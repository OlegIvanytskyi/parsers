# %%
from helper import *
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Driver [C:\Users\Oleg\.wdm\drivers\chromedriver\win32\84.0.4147.30\chromedriver.exe] found in cache

# %%
categories = {'politics' : 'politik', 'sport' : 'sport/fussball',
              'economy' : 'wirtschaft', 'career' : 'leben/karriere',
              'home' : 'leben/wohnen', 'health' : 'leben/gesundheit',
              'pets' : 'leben/tiere', 'gaming' : 'leben/games',
              'auto' : 'auto', 'travel' : 'reise',
              'cinema' : 'kino', 'food' : 'leben/genuss'}

# %%
for category, path in categories.items():
    print(f'Working with {category} category')
    
    lines = []
    
    for year in range(2000, 2021):
        print(f'Year: {year}')
        for month in range(1, 13):
            print(f'Month: {month}')
            page_num = 1
            month_str = f'0{month}' if month < 10 else str(month)
            
            while True:
                url = f'https://www.merkur.de/{path}/archiv-{year}-{month_str}/index-vc-376989-{page_num}.html#id-swiper-376989'

                try:
                    driver.get(url)
                    page = driver.page_source
                    soup = BeautifulSoup(page, 'html.parser')
                    
                    if page_num == 1:
                        try:
                            limit = int(soup.find('div', class_='id-Swiper-navcount').text.split()[-1])
                            print(f'Number of pages: {limit}')
                        except AttributeError:
                            limit = 1
                        
                    div = soup.find('div', class_='id-LB id-LB--XL2 id-Teaser id-Teaser-el--listLeftStyle--LB')
                    if div is None:
                        break

                    divs = div.find_all('div', class_='id-Teaser-el-content')
                    if divs == []:
                        break
                        
                    for div in divs:
                        teaser_headline = div.find('h3', class_='id-Teaser-el-content-headline')
                        teaser = div.find('div', class_='id-Teaser-el-content-text')

                        if None in (teaser_headline, teaser):
                            continue

                        teaser_headline = teaser_headline.text.strip()
                        teaser = teaser.text.strip()

                        lines.append(teaser_headline)
                        lines.append(teaser)
                        
                        if len(lines) % 100 == 0:
                            print(f'Scraped {len(lines)} lines')

                    page_num += 1
                    if page_num > limit:
                        break
                except:
                    break
                
    print(f'Finished working with {category} category. Scraped {len(lines)} lines\n\n')
    write_to_file(lines, category, 'merkur_de')
# Out:
# Working with politics category
# Year: 2020
# Month: 1
# Number of pages: 11
# Scraped 100 lines
# Scraped 200 lines
# Scraped 300 lines
# Scraped 400 lines
# Scraped 500 lines
# Scraped 600 lines
# Scraped 700 lines
# Scraped 800 lines
# Scraped 900 lines
# Scraped 1000 lines
# Scraped 1100 lines
# Scraped 1200 lines
# Scraped 1300 lines
# Month: 2
# Number of pages: 11
# Scraped 1400 lines
# Scraped 1500 lines
# Scraped 1600 lines
# Scraped 1700 lines
# Scraped 1800 lines
# Scraped 1900 lines
# Scraped 2000 lines
# Scraped 2100 lines
# Scraped 2200 lines
# Scraped 2300 lines
# Scraped 2400 lines
# Scraped 2500 lines
# Month: 3
# Number of pages: 11
# Scraped 2600 lines
# Scraped 2700 lines
# Scraped 2800 lines
# Scraped 2900 lines
# Scraped 3000 lines
# Scraped 3100 lines
# Scraped 3200 lines
# Scraped 3300 lines
# Scraped 3400 lines
# Scraped 3500 lines
# Scraped 3600 lines
# Scraped 3700 lines
# Month: 4
# Number of pages: 10
# Scraped 3800 lines
# Scraped 3900 lines
# Scraped 4000 lines
# Scraped 4100 lines
# Scraped 4200 lines
# Scraped 4300 lines
# Scraped 4400 lines
# Scraped 4500 lines
# Scraped 4600 lines
# Scraped 4700 lines
# Scraped 4800 lines
# Scraped 4900 lines
# Month: 5
# Number of pages: 10
# Scraped 5000 lines
# Scraped 5100 lines
# Scraped 5200 lines
# Scraped 5300 lines
# Scraped 5400 lines
# Scraped 5500 lines
# Scraped 5600 lines
# Month: 6
# Number of pages: 11
# Scraped 5700 lines
# Scraped 5800 lines
# Scraped 5900 lines
# Scraped 6000 lines
# Scraped 6100 lines
# Scraped 6200 lines
# Scraped 6300 lines
# Scraped 6400 lines
# Scraped 6500 lines
# Scraped 6600 lines
# Scraped 6700 lines
# Scraped 6800 lines
# Month: 7
# Number of pages: 12
# Scraped 6900 lines
# Scraped 7000 lines
# Scraped 7100 lines
# Scraped 7200 lines
# Scraped 7300 lines
# Scraped 7400 lines
# Scraped 7500 lines
# Scraped 7600 lines
# Scraped 7700 lines
# Scraped 7800 lines
# Scraped 7900 lines
# Scraped 8000 lines
# Scraped 8100 lines
# Scraped 8200 lines
# Month: 8
# Number of pages: 5
# Scraped 8300 lines
# Scraped 8400 lines
# Scraped 8500 lines
# Scraped 8600 lines
# Scraped 8700 lines
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with politics category. Scraped 8744 lines
#
#
# 8744 lines of politics category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with sport category
# Year: 2020
# Month: 1
# Number of pages: 7
# Scraped 100 lines
# Scraped 200 lines
# Scraped 300 lines
# Scraped 400 lines
# Scraped 500 lines
# Scraped 600 lines
# Scraped 700 lines
# Scraped 800 lines
# Month: 2
# Number of pages: 9
# Scraped 900 lines
# Scraped 1000 lines
# Scraped 1100 lines
# Scraped 1200 lines
# Scraped 1300 lines
# Scraped 1400 lines
# Scraped 1500 lines
# Scraped 1600 lines
# Scraped 1700 lines
# Scraped 1800 lines
# Month: 3
# Scraped 1900 lines
# Scraped 2000 lines
# Month: 4
# Scraped 2100 lines
# Month: 5
# Scraped 2200 lines
# Month: 6
# Scraped 2300 lines
# Month: 7
# Scraped 2400 lines
# Month: 8
# Scraped 2500 lines
# Scraped 2600 lines
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with sport category. Scraped 2610 lines
#
#
# 2610 lines of sport category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with economy category
# Year: 2020
# Month: 1
# Scraped 100 lines
# Month: 2
# Scraped 200 lines
# Month: 3
# Scraped 300 lines
# Month: 4
# Scraped 400 lines
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with economy category. Scraped 480 lines
#
#
# 480 lines of economy category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with career category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with career category. Scraped 0 lines
#
#
# 0 lines of career category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with home category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with home category. Scraped 0 lines
#
#
# 0 lines of home category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with health category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Scraped 100 lines
# Month: 5
# Scraped 200 lines
# Month: 6
# Scraped 300 lines
# Month: 7
# Scraped 400 lines
# Month: 8
# Scraped 500 lines
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with health category. Scraped 598 lines
#
#
# 598 lines of health category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with pets category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Scraped 100 lines
# Month: 5
# Month: 6
# Month: 7
# Scraped 200 lines
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with pets category. Scraped 224 lines
#
#
# 224 lines of pets category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with gaming category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with gaming category. Scraped 0 lines
#
#
# 0 lines of gaming category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with auto category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with auto category. Scraped 0 lines
#
#
# 0 lines of auto category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with travel category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with travel category. Scraped 0 lines
#
#
# 0 lines of travel category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with cinema category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with cinema category. Scraped 0 lines
#
#
# 0 lines of cinema category have been scraped from merkur_de
#
# ______________________________________________________________________________
# Working with food category
# Year: 2020
# Month: 1
# Month: 2
# Month: 3
# Month: 4
# Month: 5
# Month: 6
# Month: 7
# Month: 8
# Month: 9
# Month: 10
# Month: 11
# Month: 12
# Finished working with food category. Scraped 0 lines
#
#
# 0 lines of food category have been scraped from merkur_de
#
# ______________________________________________________________________________
