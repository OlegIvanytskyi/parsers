# %%
from helper import *
driver = webdriver.Chrome()

# %%
categories = {'travel' : 'reise', 'politics' : 'politik',
              'economy' : 'wirtschaft', 'food' : 'leben/genuss',
              'health' : 'leben/gesundheit', 'career' : 'leben/karriere',
              'pets' : 'leben/tiere' , 'gaming' : 'leben/games',
              'cinema' : 'leben/serien', 'auto' : 'auto',
              'sport' : 'sport', 'stars' : 'stars'}

# %%
for category, path in categories.items():
    print(f'Working with {category} category')
    
    articles = []
    page_num = 1
    
    for year in range(2009, 2021):
        print(f'Year: {year}')
        for month in range(1, 13):
            print(f'Month: {month}')
            
            page_num = 1
            month_str = f'0{month}' if month < 10 else str(month)
            
            while True:
                time.sleep(5)
                url = f'https://www.tz.de/{path}/archiv-{year}-{month_str}/index-vc-399169-{page_num}.html#id-swiper-399169'
                
                try:
                    driver.get(url)
                    page = driver.page_source
                    soup = BeautifulSoup(page, 'html.parser')

                    if page_num == 1:
                        page_counter = soup.find('div', class_='id-Swiper-navcountnavnew-inner')
                        if page_counter is None:
                            limit = 1
                        else:
                            limit = len(page_counter.find_all('a'))
                        print(f'Number of pages: {limit}')

                    div = soup.find('div', class_='id-LB id-LB--XL2 id-Teaser id-Teaser-el--listLeftStyle--LB')
                    if div is None:
                        break

                    divs = div.find_all('div', class_='id-LB-e--XL6_0c') + div.find_all('div', class_='id-LB-e--XL6_6')
                    if divs == []:
                        break

                    for div in divs:
                        teaser_headline = div.find('span', class_='id-Teaser-el-content-headline-text')
                        teaser = div.find('span', class_='id-Teaser-el-content-text-text')

                        if None in (teaser_headline, teaser):
                            continue

                        teaser_headline = teaser_headline.text.strip()
                        teaser = teaser.text.strip()

                        articles.append([teaser_headline, teaser])

                        if len(articles) % 100 == 0:
                            print(f'Scraped {len(articles)} articles')

                    page_num += 1
                    if page_num > limit:
                        break
                except:
                    break
        
    print(f'Finished working with {category} category. Scraped {len(articles)} articles')
    write_to_file(articles, category, 'tz_de')
# Out:
# Working with travel category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 100 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 200 articles
# Month: 12
# Number of pages: 1
# Scraped 300 articles
# Year: 2010
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 400 articles
# Month: 3
# Number of pages: 1
# Scraped 500 articles
# Month: 4
# Number of pages: 1
# Scraped 600 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 700 articles
# Month: 7
# Number of pages: 1
# Scraped 800 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 900 articles
# Month: 10
# Number of pages: 1
# Scraped 1000 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 1100 articles
# Year: 2011
# Month: 1
# Number of pages: 1
# Scraped 1200 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 1300 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 1400 articles
# Month: 6
# Number of pages: 1
# Scraped 1500 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 1600 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 1700 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 1800 articles
# Year: 2012
# Month: 1
# Number of pages: 1
# Scraped 1900 articles
# Month: 2
# Number of pages: 1
# Scraped 2000 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 2100 articles
# Month: 5
# Number of pages: 1
# Scraped 2200 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 2300 articles
# Month: 8
# Number of pages: 1
# Scraped 2400 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 2500 articles
# Month: 11
# Number of pages: 1
# Scraped 2600 articles
# Month: 12
# Number of pages: 1
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 2700 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 2800 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 2900 articles
# Month: 6
# Number of pages: 1
# Scraped 3000 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 3100 articles
# Month: 9
# Number of pages: 1
# Scraped 3200 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 3300 articles
# Month: 12
# Number of pages: 1
# Year: 2014
# Month: 1
# Number of pages: 1
# Scraped 3400 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 3500 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 3600 articles
# Month: 6
# Number of pages: 1
# Scraped 3700 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 3800 articles
# Month: 9
# Number of pages: 1
# Scraped 3900 articles
# Month: 10
# Number of pages: 1
# Scraped 4000 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 4100 articles
# Year: 2015
# Month: 1
# Number of pages: 1
# Scraped 4200 articles
# Month: 2
# Number of pages: 1
# Scraped 4300 articles
# Month: 3
# Number of pages: 1
# Scraped 4400 articles
# Month: 4
# Number of pages: 1
# Scraped 4500 articles
# Month: 5
# Number of pages: 1
# Scraped 4600 articles
# Month: 6
# Number of pages: 1
# Scraped 4700 articles
# Month: 7
# Number of pages: 2
# Scraped 4800 articles
# Month: 8
# Number of pages: 1
# Scraped 4900 articles
# Month: 9
# Number of pages: 1
# Scraped 5000 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 5100 articles
# Month: 12
# Number of pages: 1
# Scraped 5200 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 5300 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 5400 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 5500 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 5600 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 5700 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 5800 articles
# Year: 2017
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 5900 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 6000 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 6100 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 6200 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 6300 articles
# Month: 12
# Number of pages: 1
# Scraped 6400 articles
# Year: 2018
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 6500 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 6600 articles
# Month: 5
# Number of pages: 1
# Scraped 6700 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 6800 articles
# Month: 8
# Number of pages: 1
# Scraped 6900 articles
# Month: 9
# Number of pages: 1
# Scraped 7000 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 7100 articles
# Month: 12
# Number of pages: 1
# Year: 2019
# Month: 1
# Number of pages: 1
# Scraped 7200 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 7300 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 7400 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 7500 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 7600 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 7700 articles
# Month: 12
# Number of pages: 1
# Scraped 7800 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 7900 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 8000 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with travel category. Scraped 8064 articles
# 8064 articles of travel category scraped from tz_de
#
# Working with politics category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 0
# Scraped 100 articles
# Month: 6
# Number of pages: 1
# Scraped 200 articles
# Month: 7
# Number of pages: 1
# Scraped 300 articles
# Month: 8
# Number of pages: 1
# Scraped 400 articles
# Month: 9
# Number of pages: 1
# Scraped 500 articles
# Scraped 600 articles
# Month: 10
# Number of pages: 1
# Scraped 700 articles
# Month: 11
# Number of pages: 1
# Scraped 800 articles
# Month: 12
# Number of pages: 1
# Scraped 900 articles
# Year: 2010
# Month: 1
# Number of pages: 1
# Scraped 1000 articles
# Month: 2
# Number of pages: 1
# Scraped 1100 articles
# Scraped 1200 articles
# Month: 3
# Number of pages: 1
# Scraped 1300 articles
# Month: 4
# Number of pages: 1
# Scraped 1400 articles
# Month: 5
# Number of pages: 1
# Scraped 1500 articles
# Month: 6
# Number of pages: 1
# Scraped 1600 articles
# Month: 7
# Number of pages: 1
# Scraped 1700 articles
# Scraped 1800 articles
# Month: 8
# Number of pages: 1
# Scraped 1900 articles
# Month: 9
# Number of pages: 1
# Scraped 2000 articles
# Month: 10
# Number of pages: 1
# Scraped 2100 articles
# Month: 11
# Number of pages: 1
# Scraped 2200 articles
# Month: 12
# Number of pages: 1
# Scraped 2300 articles
# Scraped 2400 articles
# Year: 2011
# Month: 1
# Number of pages: 1
# Scraped 2500 articles
# Month: 2
# Number of pages: 1
# Scraped 2600 articles
# Month: 3
# Number of pages: 1
# Scraped 2700 articles
# Month: 4
# Number of pages: 1
# Scraped 2800 articles
# Month: 5
# Number of pages: 1
# Scraped 2900 articles
# Scraped 3000 articles
# Month: 6
# Number of pages: 1
# Scraped 3100 articles
# Month: 7
# Number of pages: 1
# Scraped 3200 articles
# Month: 8
# Number of pages: 1
# Scraped 3300 articles
# Month: 9
# Number of pages: 1
# Scraped 3400 articles
# Month: 10
# Number of pages: 1
# Scraped 3500 articles
# Scraped 3600 articles
# Month: 11
# Number of pages: 1
# Scraped 3700 articles
# Month: 12
# Number of pages: 1
# Scraped 3800 articles
# Year: 2012
# Month: 1
# Number of pages: 1
# Scraped 3900 articles
# Month: 2
# Number of pages: 1
# Scraped 4000 articles
# Month: 3
# Number of pages: 1
# Scraped 4100 articles
# Month: 4
# Number of pages: 1
# Scraped 4200 articles
# Scraped 4300 articles
# Month: 5
# Number of pages: 1
# Scraped 4400 articles
# Month: 6
# Number of pages: 0
# Scraped 4500 articles
# Month: 7
# Number of pages: 1
# Scraped 4600 articles
# Month: 8
# Number of pages: 1
# Scraped 4700 articles
# Month: 9
# Number of pages: 1
# Scraped 4800 articles
# Scraped 4900 articles
# Month: 10
# Number of pages: 1
# Scraped 5000 articles
# Month: 11
# Number of pages: 1
# Scraped 5100 articles
# Month: 12
# Number of pages: 1
# Scraped 5200 articles
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 5300 articles
# Month: 2
# Number of pages: 1
# Scraped 5400 articles
# Scraped 5500 articles
# Month: 3
# Number of pages: 1
# Scraped 5600 articles
# Month: 4
# Number of pages: 1
# Scraped 5700 articles
# Month: 5
# Number of pages: 1
# Scraped 5800 articles
# Month: 6
# Number of pages: 1
# Scraped 5900 articles
# Month: 7
# Number of pages: 1
# Scraped 6000 articles
# Scraped 6100 articles
# Month: 8
# Number of pages: 1
# Scraped 6200 articles
# Month: 9
# Number of pages: 1
# Scraped 6300 articles
# Month: 10
# Number of pages: 1
# Scraped 6400 articles
# Month: 11
# Number of pages: 1
# Scraped 6500 articles
# Month: 12
# Number of pages: 1
# Scraped 6600 articles
# Scraped 6700 articles
# Year: 2014
# Month: 1
# Number of pages: 1
# Scraped 6800 articles
# Month: 2
# Number of pages: 1
# Scraped 6900 articles
# Month: 3
# Number of pages: 1
# Scraped 7000 articles
# Month: 4
# Number of pages: 1
# Scraped 7100 articles
# Month: 5
# Number of pages: 1
# Scraped 7200 articles
# Month: 6
# Number of pages: 1
# Scraped 7300 articles
# Scraped 7400 articles
# Month: 7
# Number of pages: 1
# Scraped 7500 articles
# Month: 8
# Number of pages: 1
# Scraped 7600 articles
# Month: 9
# Number of pages: 1
# Scraped 7700 articles
# Month: 10
# Number of pages: 1
# Scraped 7800 articles
# Month: 11
# Number of pages: 1
# Scraped 7900 articles
# Scraped 8000 articles
# Month: 12
# Number of pages: 1
# Scraped 8100 articles
# Year: 2015
# Month: 1
# Number of pages: 1
# Scraped 8200 articles
# Month: 2
# Number of pages: 1
# Scraped 8300 articles
# Month: 3
# Number of pages: 1
# Scraped 8400 articles
# Month: 4
# Number of pages: 1
# Scraped 8500 articles
# Scraped 8600 articles
# Month: 5
# Number of pages: 1
# Scraped 8700 articles
# Month: 6
# Number of pages: 1
# Scraped 8800 articles
# Month: 7
# Number of pages: 1
# Scraped 8900 articles
# Month: 8
# Number of pages: 1
# Scraped 9000 articles
# Month: 9
# Number of pages: 1
# Scraped 9100 articles
# Scraped 9200 articles
# Month: 10
# Number of pages: 1
# Scraped 9300 articles
# Month: 11
# Number of pages: 1
# Scraped 9400 articles
# Month: 12
# Number of pages: 1
# Scraped 9500 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Scraped 9600 articles
# Month: 2
# Number of pages: 1
# Scraped 9700 articles
# Scraped 9800 articles
# Month: 3
# Number of pages: 1
# Scraped 9900 articles
# Month: 4
# Number of pages: 1
# Scraped 10000 articles
# Month: 5
# Number of pages: 1
# Scraped 10100 articles
# Month: 6
# Number of pages: 1
# Scraped 10200 articles
# Month: 7
# Number of pages: 1
# Scraped 10300 articles
# Scraped 10400 articles
# Month: 8
# Number of pages: 1
# Scraped 10500 articles
# Month: 9
# Number of pages: 1
# Scraped 10600 articles
# Month: 10
# Number of pages: 1
# Scraped 10700 articles
# Month: 11
# Number of pages: 1
# Scraped 10800 articles
# Month: 12
# Number of pages: 1
# Scraped 10900 articles
# Scraped 11000 articles
# Year: 2017
# Month: 1
# Number of pages: 1
# Scraped 11100 articles
# Month: 2
# Number of pages: 1
# Scraped 11200 articles
# Month: 3
# Number of pages: 1
# Scraped 11300 articles
# Month: 4
# Number of pages: 1
# Scraped 11400 articles
# Month: 5
# Number of pages: 1
# Scraped 11500 articles
# Scraped 11600 articles
# Month: 6
# Number of pages: 1
# Scraped 11700 articles
# Month: 7
# Number of pages: 1
# Scraped 11800 articles
# Month: 8
# Number of pages: 1
# Scraped 11900 articles
# Month: 9
# Number of pages: 1
# Scraped 12000 articles
# Month: 10
# Number of pages: 1
# Scraped 12100 articles
# Scraped 12200 articles
# Month: 11
# Number of pages: 1
# Scraped 12300 articles
# Month: 12
# Number of pages: 1
# Scraped 12400 articles
# Year: 2018
# Month: 1
# Number of pages: 1
# Scraped 12500 articles
# Month: 2
# Number of pages: 5
# Scraped 12600 articles
# Scraped 12700 articles
# Scraped 12800 articles
# Scraped 12900 articles
# Scraped 13000 articles
# Month: 3
# Number of pages: 5
# Scraped 13100 articles
# Scraped 13200 articles
# Scraped 13300 articles
# Scraped 13400 articles
# Scraped 13500 articles
# Scraped 13600 articles
# Month: 4
# Number of pages: 5
# Scraped 13700 articles
# Scraped 13800 articles
# Scraped 13900 articles
# Scraped 14000 articles
# Scraped 14100 articles
# Scraped 14200 articles
# Month: 5
# Number of pages: 5
# Scraped 14300 articles
# Scraped 14400 articles
# Scraped 14500 articles
# Scraped 14600 articles
# Scraped 14700 articles
# Scraped 14800 articles
# Month: 6
# Number of pages: 5
# Scraped 14900 articles
# Scraped 15000 articles
# Scraped 15100 articles
# Scraped 15200 articles
# Scraped 15300 articles
# Month: 7
# Number of pages: 4
# Scraped 15400 articles
# Scraped 15500 articles
# Scraped 15600 articles
# Scraped 15700 articles
# Scraped 15800 articles
# Month: 8
# Number of pages: 1
# Scraped 15900 articles
# Month: 9
# Number of pages: 1
# Scraped 16000 articles
# Scraped 16100 articles
# Month: 10
# Number of pages: 1
# Scraped 16200 articles
# Month: 11
# Number of pages: 1
# Scraped 16300 articles
# Month: 12
# Number of pages: 1
# Scraped 16400 articles
# Year: 2019
# Month: 1
# Number of pages: 1
# Scraped 16500 articles
# Month: 2
# Number of pages: 1
# Scraped 16600 articles
# Scraped 16700 articles
# Month: 3
# Number of pages: 1
# Scraped 16800 articles
# Month: 4
# Number of pages: 1
# Scraped 16900 articles
# Month: 5
# Number of pages: 1
# Scraped 17000 articles
# Month: 6
# Number of pages: 1
# Scraped 17100 articles
# Month: 7
# Number of pages: 1
# Scraped 17200 articles
# Scraped 17300 articles
# Month: 8
# Number of pages: 1
# Scraped 17400 articles
# Month: 9
# Number of pages: 1
# Scraped 17500 articles
# Month: 10
# Number of pages: 1
# Scraped 17600 articles
# Month: 11
# Number of pages: 1
# Scraped 17700 articles
# Month: 12
# Number of pages: 1
# Scraped 17800 articles
# Scraped 17900 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 18000 articles
# Month: 2
# Number of pages: 1
# Scraped 18100 articles
# Month: 3
# Number of pages: 1
# Scraped 18200 articles
# Month: 4
# Number of pages: 1
# Scraped 18300 articles
# Month: 5
# Number of pages: 1
# Scraped 18400 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with politics category. Scraped 18416 articles
# 18416 articles of politics category scraped from tz_de
#
# Working with economy category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 100 articles
# Month: 6
# Number of pages: 1
# Scraped 200 articles
# Month: 7
# Number of pages: 1
# Scraped 300 articles
# Month: 8
# Number of pages: 1
# Scraped 400 articles
# Month: 9
# Number of pages: 1
# Scraped 500 articles
# Scraped 600 articles
# Month: 10
# Number of pages: 1
# Scraped 700 articles
# Month: 11
# Number of pages: 1
# Scraped 800 articles
# Month: 12
# Number of pages: 1
# Scraped 900 articles
# Year: 2010
# Month: 1
# Number of pages: 1
# Scraped 1000 articles
# Month: 2
# Number of pages: 1
# Scraped 1100 articles
# Scraped 1200 articles
# Month: 3
# Number of pages: 1
# Scraped 1300 articles
# Month: 4
# Number of pages: 1
# Scraped 1400 articles
# Month: 5
# Number of pages: 1
# Scraped 1500 articles
# Month: 6
# Number of pages: 1
# Scraped 1600 articles
# Month: 7
# Number of pages: 1
# Scraped 1700 articles
# Scraped 1800 articles
# Month: 8
# Number of pages: 1
# Scraped 1900 articles
# Month: 9
# Number of pages: 1
# Scraped 2000 articles
# Month: 10
# Number of pages: 1
# Scraped 2100 articles
# Month: 11
# Number of pages: 1
# Scraped 2200 articles
# Month: 12
# Number of pages: 1
# Scraped 2300 articles
# Scraped 2400 articles
# Year: 2011
# Month: 1
# Number of pages: 1
# Scraped 2500 articles
# Month: 2
# Number of pages: 1
# Scraped 2600 articles
# Month: 3
# Number of pages: 1
# Scraped 2700 articles
# Month: 4
# Number of pages: 1
# Scraped 2800 articles
# Month: 5
# Number of pages: 1
# Scraped 2900 articles
# Scraped 3000 articles
# Month: 6
# Number of pages: 1
# Scraped 3100 articles
# Month: 7
# Number of pages: 1
# Scraped 3200 articles
# Month: 8
# Number of pages: 1
# Scraped 3300 articles
# Month: 9
# Number of pages: 1
# Scraped 3400 articles
# Month: 10
# Number of pages: 1
# Scraped 3500 articles
# Scraped 3600 articles
# Month: 11
# Number of pages: 1
# Scraped 3700 articles
# Month: 12
# Number of pages: 3
# Scraped 3800 articles
# Scraped 3900 articles
# Scraped 4000 articles
# Year: 2012
# Month: 1
# Number of pages: 1
# Scraped 4100 articles
# Month: 2
# Number of pages: 1
# Scraped 4200 articles
# Month: 3
# Number of pages: 1
# Scraped 4300 articles
# Month: 4
# Number of pages: 1
# Scraped 4400 articles
# Scraped 4500 articles
# Month: 5
# Number of pages: 1
# Scraped 4600 articles
# Month: 6
# Number of pages: 1
# Scraped 4700 articles
# Month: 7
# Number of pages: 1
# Scraped 4800 articles
# Month: 8
# Number of pages: 1
# Scraped 4900 articles
# Month: 9
# Number of pages: 1
# Scraped 5000 articles
# Month: 10
# Number of pages: 1
# Scraped 5100 articles
# Scraped 5200 articles
# Month: 11
# Number of pages: 1
# Scraped 5300 articles
# Month: 12
# Number of pages: 1
# Scraped 5400 articles
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 5500 articles
# Month: 2
# Number of pages: 1
# Scraped 5600 articles
# Month: 3
# Number of pages: 1
# Scraped 5700 articles
# Scraped 5800 articles
# Month: 4
# Number of pages: 1
# Scraped 5900 articles
# Month: 5
# Number of pages: 1
# Scraped 6000 articles
# Month: 6
# Number of pages: 1
# Scraped 6100 articles
# Month: 7
# Number of pages: 1
# Scraped 6200 articles
# Month: 8
# Number of pages: 1
# Scraped 6300 articles
# Scraped 6400 articles
# Month: 9
# Number of pages: 1
# Scraped 6500 articles
# Month: 10
# Number of pages: 1
# Scraped 6600 articles
# Month: 11
# Number of pages: 1
# Scraped 6700 articles
# Month: 12
# Number of pages: 1
# Scraped 6800 articles
# Year: 2014
# Month: 1
# Number of pages: 1
# Scraped 6900 articles
# Scraped 7000 articles
# Month: 2
# Number of pages: 1
# Scraped 7100 articles
# Month: 3
# Number of pages: 1
# Scraped 7200 articles
# Month: 4
# Number of pages: 1
# Scraped 7300 articles
# Month: 5
# Number of pages: 1
# Scraped 7400 articles
# Month: 6
# Number of pages: 1
# Scraped 7500 articles
# Scraped 7600 articles
# Month: 7
# Number of pages: 1
# Scraped 7700 articles
# Month: 8
# Number of pages: 1
# Scraped 7800 articles
# Month: 9
# Number of pages: 1
# Scraped 7900 articles
# Month: 10
# Number of pages: 1
# Scraped 8000 articles
# Month: 11
# Number of pages: 1
# Scraped 8100 articles
# Scraped 8200 articles
# Month: 12
# Number of pages: 1
# Scraped 8300 articles
# Year: 2015
# Month: 1
# Number of pages: 1
# Scraped 8400 articles
# Month: 2
# Number of pages: 1
# Scraped 8500 articles
# Month: 3
# Number of pages: 1
# Scraped 8600 articles
# Month: 4
# Number of pages: 1
# Scraped 8700 articles
# Scraped 8800 articles
# Month: 5
# Number of pages: 1
# Scraped 8900 articles
# Month: 6
# Number of pages: 1
# Scraped 9000 articles
# Month: 7
# Number of pages: 1
# Scraped 9100 articles
# Month: 8
# Number of pages: 1
# Scraped 9200 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 9300 articles
# Scraped 9400 articles
# Month: 12
# Number of pages: 1
# Scraped 9500 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Scraped 9600 articles
# Month: 2
# Number of pages: 1
# Scraped 9700 articles
# Month: 3
# Number of pages: 1
# Scraped 9800 articles
# Month: 4
# Number of pages: 1
# Scraped 9900 articles
# Scraped 10000 articles
# Month: 5
# Number of pages: 1
# Scraped 10100 articles
# Month: 6
# Number of pages: 1
# Scraped 10200 articles
# Month: 7
# Number of pages: 1
# Scraped 10300 articles
# Month: 8
# Number of pages: 1
# Scraped 10400 articles
# Month: 9
# Number of pages: 1
# Scraped 10500 articles
# Scraped 10600 articles
# Month: 10
# Number of pages: 1
# Scraped 10700 articles
# Month: 11
# Number of pages: 1
# Scraped 10800 articles
# Month: 12
# Number of pages: 1
# Scraped 10900 articles
# Year: 2017
# Month: 1
# Number of pages: 1
# Scraped 11000 articles
# Month: 2
# Number of pages: 1
# Scraped 11100 articles
# Scraped 11200 articles
# Month: 3
# Number of pages: 1
# Scraped 11300 articles
# Month: 4
# Number of pages: 1
# Scraped 11400 articles
# Month: 5
# Number of pages: 1
# Scraped 11500 articles
# Month: 6
# Number of pages: 1
# Scraped 11600 articles
# Month: 7
# Number of pages: 1
# Scraped 11700 articles
# Scraped 11800 articles
# Month: 8
# Number of pages: 1
# Scraped 11900 articles
# Month: 9
# Number of pages: 1
# Scraped 12000 articles
# Month: 10
# Number of pages: 1
# Scraped 12100 articles
# Month: 11
# Number of pages: 1
# Scraped 12200 articles
# Month: 12
# Number of pages: 1
# Scraped 12300 articles
# Scraped 12400 articles
# Year: 2018
# Month: 1
# Number of pages: 1
# Scraped 12500 articles
# Month: 2
# Number of pages: 1
# Scraped 12600 articles
# Month: 3
# Number of pages: 1
# Scraped 12700 articles
# Month: 4
# Number of pages: 1
# Scraped 12800 articles
# Month: 5
# Number of pages: 1
# Scraped 12900 articles
# Scraped 13000 articles
# Month: 6
# Number of pages: 1
# Scraped 13100 articles
# Month: 7
# Number of pages: 1
# Scraped 13200 articles
# Month: 8
# Number of pages: 1
# Scraped 13300 articles
# Month: 9
# Number of pages: 1
# Scraped 13400 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 13500 articles
# Month: 12
# Number of pages: 1
# Scraped 13600 articles
# Year: 2019
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 13700 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 13800 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 13900 articles
# Month: 7
# Number of pages: 1
# Scraped 14000 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 14100 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 14200 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 14300 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with economy category. Scraped 14395 articles
# 14395 articles of economy category scraped from tz_de
#
# Working with food category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2010
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2011
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2012
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2013
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 100 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 200 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2014
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 300 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 400 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 500 articles
# Month: 12
# Number of pages: 1
# Year: 2015
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 600 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 700 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 800 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 900 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2016
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 1000 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 1100 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2017
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 1200 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2018
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2019
# Month: 1
# Number of pages: 1
# Scraped 1300 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 1400 articles
# Month: 12
# Number of pages: 1
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 1500 articles
# Month: 3
# Number of pages: 1
# Scraped 1600 articles
# Month: 4
# Number of pages: 1
# Scraped 1700 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with food category. Scraped 1726 articles
# 1726 articles of food category scraped from tz_de
#
# Working with health category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2010
# Month: 1
# Number of pages: 1
# Scraped 100 articles
# Month: 2
# Number of pages: 1
# Scraped 200 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 300 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 400 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2011
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 500 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 600 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 700 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 800 articles
# Month: 12
# Number of pages: 1
# Year: 2012
# Month: 1
# Number of pages: 1
# Scraped 900 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 1000 articles
# Month: 4
# Number of pages: 1
# Scraped 1100 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 1200 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 1300 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 1400 articles
# Month: 11
# Number of pages: 1
# Scraped 1500 articles
# Month: 12
# Number of pages: 1
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 1600 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 1700 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 1800 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 1900 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 2000 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2014
# Month: 1
# Number of pages: 1
# Scraped 2100 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 2200 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 2300 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 2400 articles
# Month: 8
# Number of pages: 1
# Scraped 2500 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 2600 articles
# Month: 11
# Number of pages: 1
# Scraped 2700 articles
# Month: 12
# Number of pages: 1
# Year: 2015
# Month: 1
# Number of pages: 1
# Scraped 2800 articles
# Month: 2
# Number of pages: 1
# Scraped 2900 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 3000 articles
# Month: 5
# Number of pages: 1
# Scraped 3100 articles
# Month: 6
# Number of pages: 1
# Scraped 3200 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 3300 articles
# Month: 9
# Number of pages: 1
# Scraped 3400 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 3500 articles
# Month: 12
# Number of pages: 1
# Scraped 3600 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 3700 articles
# Month: 3
# Number of pages: 1
# Scraped 3800 articles
# Month: 4
# Number of pages: 1
# Scraped 3900 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 4000 articles
# Month: 7
# Number of pages: 1
# Scraped 4100 articles
# Month: 8
# Number of pages: 1
# Scraped 4200 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 4300 articles
# Month: 11
# Number of pages: 1
# Scraped 4400 articles
# Month: 12
# Number of pages: 1
# Year: 2017
# Month: 1
# Number of pages: 1
# Scraped 4500 articles
# Month: 2
# Number of pages: 1
# Scraped 4600 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 4700 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 4800 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 4900 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 5000 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 5100 articles
# Year: 2018
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 5200 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 5300 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 5400 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 5500 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 5600 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2019
# Month: 1
# Number of pages: 1
# Scraped 5700 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 5800 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 5900 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 6000 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 6100 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 6200 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 6300 articles
# Month: 3
# Number of pages: 1
# Scraped 6400 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with health category. Scraped 6493 articles
# 6493 articles of health category scraped from tz_de
#
# Working with career category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2010
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 100 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2011
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 200 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 300 articles
# Month: 12
# Number of pages: 1
# Year: 2012
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 400 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 500 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 600 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2014
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 700 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 800 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 900 articles
# Year: 2015
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 1000 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 1100 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 1200 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 1300 articles
# Month: 12
# Number of pages: 1
# Year: 2016
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 1400 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 1500 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 1600 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 1700 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2017
# Month: 1
# Number of pages: 1
# Scraped 1800 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 1900 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 2000 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 2100 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2018
# Month: 1
# Number of pages: 1
# Scraped 2200 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 2300 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 2400 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Scraped 2500 articles
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 2600 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 2700 articles
# Year: 2019
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 2800 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 2900 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Scraped 3000 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 3100 articles
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 3200 articles
# Month: 12
# Number of pages: 1
# Scraped 3300 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 3400 articles
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 3500 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with career category. Scraped 3523 articles
# 3523 articles of career category scraped from tz_de
#
# Working with pets category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2010
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2011
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2012
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Scraped 100 articles
# Month: 12
# Number of pages: 1
# Scraped 200 articles
# Year: 2013
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2014
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 300 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2015
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 400 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 500 articles
# Month: 7
# Number of pages: 1
# Scraped 600 articles
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 700 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Scraped 800 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 900 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 1000 articles
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Scraped 1100 articles
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2017
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 1200 articles
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2018
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2019
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with pets category. Scraped 1222 articles
# 1222 articles of pets category scraped from tz_de
#
# Working with gaming category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2010
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2011
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2012
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2013
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2014
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2015
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2016
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2017
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2018
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2019
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Scraped 100 articles
# Month: 10
# Number of pages: 1
# Scraped 200 articles
# Month: 11
# Number of pages: 1
# Scraped 300 articles
# Month: 12
# Number of pages: 1
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 400 articles
# Month: 2
# Number of pages: 1
# Scraped 500 articles
# Scraped 600 articles
# Month: 3
# Number of pages: 1
# Scraped 700 articles
# Month: 4
# Number of pages: 1
# Scraped 800 articles
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with gaming category. Scraped 869 articles
# 869 articles of gaming category scraped from tz_de
#
# Working with cinema category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2010
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2011
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Year: 2012
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# ...
# 9598 articles of auto category scraped from tz_de
#
# Working with sport category
# Year: 2009
# Month: 1
# Number of pages: 1
# Scraped 100 articles
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 200 articles
# Scraped 300 articles
# Month: 4
# Number of pages: 1
# Scraped 400 articles
# Month: 5
# Number of pages: 1
# Scraped 500 articles
# Month: 6
# Number of pages: 1
# Scraped 600 articles
# Month: 7
# Number of pages: 1
# Scraped 700 articles
# Month: 8
# Number of pages: 1
# Scraped 800 articles
# Scraped 900 articles
# Month: 9
# Number of pages: 1
# Scraped 1000 articles
# Month: 10
# Number of pages: 1
# Scraped 1100 articles
# Month: 11
# Number of pages: 1
# Scraped 1200 articles
# Month: 12
# Number of pages: 1
# Scraped 1300 articles
# Year: 2010
# Month: 1
# Number of pages: 1
# Scraped 1400 articles
# Scraped 1500 articles
# Month: 2
# Number of pages: 1
# Scraped 1600 articles
# Month: 3
# Number of pages: 1
# Scraped 1700 articles
# Month: 4
# Number of pages: 1
# Scraped 1800 articles
# Month: 5
# Number of pages: 1
# Scraped 1900 articles
# Month: 6
# Number of pages: 1
# Scraped 2000 articles
# Scraped 2100 articles
# Month: 7
# Number of pages: 1
# Scraped 2200 articles
# Month: 8
# Number of pages: 1
# Scraped 2300 articles
# Month: 9
# Number of pages: 1
# Scraped 2400 articles
# Month: 10
# Number of pages: 1
# Scraped 2500 articles
# Month: 11
# Number of pages: 1
# Scraped 2600 articles
# Scraped 2700 articles
# Month: 12
# Number of pages: 1
# Scraped 2800 articles
# Year: 2011
# Month: 1
# Number of pages: 1
# Scraped 2900 articles
# Month: 2
# Number of pages: 1
# Scraped 3000 articles
# Month: 3
# Number of pages: 1
# Scraped 3100 articles
# Month: 4
# Number of pages: 1
# Scraped 3200 articles
# Scraped 3300 articles
# Month: 5
# Number of pages: 1
# Scraped 3400 articles
# Month: 6
# Number of pages: 1
# Scraped 3500 articles
# Month: 7
# Number of pages: 1
# Scraped 3600 articles
# Month: 8
# Number of pages: 1
# Scraped 3700 articles
# Month: 9
# Number of pages: 1
# Scraped 3800 articles
# Scraped 3900 articles
# Month: 10
# Number of pages: 1
# Scraped 4000 articles
# Month: 11
# Number of pages: 1
# Scraped 4100 articles
# Month: 12
# Number of pages: 1
# Scraped 4200 articles
# Year: 2012
# Month: 1
# Number of pages: 1
# Scraped 4300 articles
# Month: 2
# Number of pages: 1
# Scraped 4400 articles
# Month: 3
# Number of pages: 1
# Scraped 4500 articles
# Scraped 4600 articles
# Month: 4
# Number of pages: 1
# Scraped 4700 articles
# Month: 5
# Number of pages: 1
# Scraped 4800 articles
# Month: 6
# Number of pages: 1
# Scraped 4900 articles
# Month: 7
# Number of pages: 1
# Scraped 5000 articles
# Month: 8
# Number of pages: 1
# Scraped 5100 articles
# Scraped 5200 articles
# Month: 9
# Number of pages: 1
# Scraped 5300 articles
# Month: 10
# Number of pages: 1
# Scraped 5400 articles
# Month: 11
# Number of pages: 1
# Scraped 5500 articles
# Month: 12
# Number of pages: 1
# Scraped 5600 articles
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 5700 articles
# Month: 2
# Number of pages: 1
# Scraped 5800 articles
# Month: 3
# Number of pages: 1
# Scraped 5900 articles
# Scraped 6000 articles
# Month: 4
# Number of pages: 1
# Scraped 6100 articles
# Month: 5
# Number of pages: 1
# Scraped 6200 articles
# Month: 6
# Number of pages: 1
# Scraped 6300 articles
# Month: 7
# Number of pages: 1
# Scraped 6400 articles
# Month: 8
# Number of pages: 1
# Scraped 6500 articles
# Month: 9
# Number of pages: 1
# Scraped 6600 articles
# Month: 10
# Number of pages: 1
# Scraped 6700 articles
# Scraped 6800 articles
# Month: 11
# Number of pages: 1
# Scraped 6900 articles
# Month: 12
# Number of pages: 1
# Scraped 7000 articles
# Year: 2014
# Month: 1
# Number of pages: 1
# Scraped 7100 articles
# Month: 2
# Number of pages: 1
# Scraped 7200 articles
# Month: 3
# Number of pages: 1
# Scraped 7300 articles
# Scraped 7400 articles
# Month: 4
# Number of pages: 1
# Scraped 7500 articles
# Month: 5
# Number of pages: 1
# Scraped 7600 articles
# Month: 6
# Number of pages: 1
# Scraped 7700 articles
# Month: 7
# Number of pages: 1
# Scraped 7800 articles
# Month: 8
# Number of pages: 1
# Scraped 7900 articles
# Scraped 8000 articles
# Month: 9
# Number of pages: 1
# Scraped 8100 articles
# Month: 10
# Number of pages: 1
# Scraped 8200 articles
# Month: 11
# Number of pages: 1
# Scraped 8300 articles
# Month: 12
# Number of pages: 1
# Scraped 8400 articles
# Year: 2015
# Month: 1
# Number of pages: 1
# Scraped 8500 articles
# Month: 2
# Number of pages: 1
# Scraped 8600 articles
# Scraped 8700 articles
# Month: 3
# Number of pages: 1
# Scraped 8800 articles
# Month: 4
# Number of pages: 1
# Scraped 8900 articles
# Month: 5
# Number of pages: 1
# Scraped 9000 articles
# Month: 6
# Number of pages: 1
# Scraped 9100 articles
# Month: 7
# Number of pages: 1
# Scraped 9200 articles
# Scraped 9300 articles
# Month: 8
# Number of pages: 1
# Scraped 9400 articles
# Month: 9
# Number of pages: 1
# Scraped 9500 articles
# Month: 10
# Number of pages: 1
# Scraped 9600 articles
# Month: 11
# Number of pages: 1
# Scraped 9700 articles
# Month: 12
# Number of pages: 1
# Scraped 9800 articles
# Scraped 9900 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Scraped 10000 articles
# Month: 2
# Number of pages: 1
# Scraped 10100 articles
# Month: 3
# Number of pages: 1
# Scraped 10200 articles
# Month: 4
# Number of pages: 1
# Scraped 10300 articles
# Month: 5
# Number of pages: 1
# Scraped 10400 articles
# Scraped 10500 articles
# Month: 6
# Number of pages: 1
# Scraped 10600 articles
# Month: 7
# Number of pages: 1
# Scraped 10700 articles
# Month: 8
# Number of pages: 1
# Scraped 10800 articles
# Month: 9
# Number of pages: 1
# Scraped 10900 articles
# Month: 10
# Number of pages: 1
# Scraped 11000 articles
# Scraped 11100 articles
# Month: 11
# Number of pages: 1
# Scraped 11200 articles
# Month: 12
# Number of pages: 1
# Scraped 11300 articles
# Year: 2017
# Month: 1
# Number of pages: 1
# Scraped 11400 articles
# Month: 2
# Number of pages: 1
# Scraped 11500 articles
# Month: 3
# Number of pages: 1
# Scraped 11600 articles
# Scraped 11700 articles
# Month: 4
# Number of pages: 1
# Scraped 11800 articles
# Month: 5
# Number of pages: 1
# Scraped 11900 articles
# Month: 6
# Number of pages: 1
# Scraped 12000 articles
# Month: 7
# Number of pages: 1
# Scraped 12100 articles
# Month: 8
# Number of pages: 1
# Scraped 12200 articles
# Scraped 12300 articles
# Month: 9
# Number of pages: 1
# Scraped 12400 articles
# Month: 10
# Number of pages: 1
# Scraped 12500 articles
# Month: 11
# Number of pages: 1
# Scraped 12600 articles
# Month: 12
# Number of pages: 1
# Scraped 12700 articles
# Year: 2018
# Month: 1
# Number of pages: 1
# Scraped 12800 articles
# Scraped 12900 articles
# Month: 2
# Number of pages: 1
# Scraped 13000 articles
# Month: 3
# Number of pages: 1
# Scraped 13100 articles
# Month: 4
# Number of pages: 1
# Scraped 13200 articles
# Month: 5
# Number of pages: 1
# Scraped 13300 articles
# Month: 6
# Number of pages: 1
# Scraped 13400 articles
# Scraped 13500 articles
# Month: 7
# Number of pages: 1
# Scraped 13600 articles
# Month: 8
# Number of pages: 1
# Scraped 13700 articles
# Month: 9
# Number of pages: 1
# Scraped 13800 articles
# Month: 10
# Number of pages: 1
# Scraped 13900 articles
# Month: 11
# Number of pages: 1
# Scraped 14000 articles
# Scraped 14100 articles
# Month: 12
# Number of pages: 1
# Scraped 14200 articles
# Year: 2019
# Month: 1
# Number of pages: 1
# Scraped 14300 articles
# Month: 2
# Number of pages: 1
# Scraped 14400 articles
# Month: 3
# Number of pages: 1
# Scraped 14500 articles
# Month: 4
# Number of pages: 1
# Scraped 14600 articles
# Month: 5
# Number of pages: 1
# Scraped 14700 articles
# Scraped 14800 articles
# Month: 6
# Number of pages: 1
# Scraped 14900 articles
# Month: 7
# Number of pages: 1
# Scraped 15000 articles
# Month: 8
# Number of pages: 1
# Scraped 15100 articles
# Month: 9
# Number of pages: 1
# Scraped 15200 articles
# Month: 10
# Number of pages: 1
# Scraped 15300 articles
# Scraped 15400 articles
# Month: 11
# Number of pages: 1
# Scraped 15500 articles
# Month: 12
# Number of pages: 1
# Scraped 15600 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 15700 articles
# Month: 2
# Number of pages: 1
# Scraped 15800 articles
# Month: 3
# Number of pages: 1
# Scraped 15900 articles
# Scraped 16000 articles
# Month: 4
# Number of pages: 1
# Scraped 16100 articles
# Month: 5
# Number of pages: 1
# Scraped 16200 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with sport category. Scraped 16237 articles
# 16237 articles of sport category scraped from tz_de
#
# Working with stars category
# Year: 2009
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 100 articles
# Month: 4
# Number of pages: 1
# Scraped 200 articles
# Month: 5
# Number of pages: 1
# Scraped 300 articles
# Month: 6
# Number of pages: 1
# Scraped 400 articles
# Month: 7
# Number of pages: 1
# Scraped 500 articles
# Scraped 600 articles
# Month: 8
# Number of pages: 1
# Scraped 700 articles
# Month: 9
# Number of pages: 1
# Scraped 800 articles
# Month: 10
# Number of pages: 1
# Scraped 900 articles
# Month: 11
# Number of pages: 0
# Scraped 1000 articles
# Month: 12
# Number of pages: 1
# Scraped 1100 articles
# Scraped 1200 articles
# Year: 2010
# Month: 1
# Number of pages: 1
# Scraped 1300 articles
# Month: 2
# Number of pages: 1
# Scraped 1400 articles
# Month: 3
# Number of pages: 1
# Scraped 1500 articles
# Month: 4
# Number of pages: 1
# Scraped 1600 articles
# Month: 5
# Number of pages: 1
# Scraped 1700 articles
# Scraped 1800 articles
# Month: 6
# Number of pages: 1
# Scraped 1900 articles
# Month: 7
# Number of pages: 1
# Scraped 2000 articles
# Month: 8
# Number of pages: 1
# Scraped 2100 articles
# Month: 9
# Number of pages: 1
# Scraped 2200 articles
# Month: 10
# Number of pages: 1
# Scraped 2300 articles
# Scraped 2400 articles
# Month: 11
# Number of pages: 1
# Scraped 2500 articles
# Month: 12
# Number of pages: 0
# Scraped 2600 articles
# Year: 2011
# Month: 1
# Number of pages: 1
# Scraped 2700 articles
# Month: 2
# Number of pages: 1
# Scraped 2800 articles
# Month: 3
# Number of pages: 1
# Scraped 2900 articles
# Scraped 3000 articles
# Month: 4
# Number of pages: 1
# Scraped 3100 articles
# Month: 5
# Number of pages: 1
# Scraped 3200 articles
# Month: 6
# Number of pages: 1
# Scraped 3300 articles
# Month: 7
# Number of pages: 1
# Scraped 3400 articles
# Month: 8
# Number of pages: 1
# Scraped 3500 articles
# Scraped 3600 articles
# Month: 9
# Number of pages: 1
# Scraped 3700 articles
# Month: 10
# Number of pages: 1
# Scraped 3800 articles
# Month: 11
# Number of pages: 1
# Scraped 3900 articles
# Month: 12
# Number of pages: 1
# Scraped 4000 articles
# Year: 2012
# Month: 1
# Number of pages: 1
# Scraped 4100 articles
# Scraped 4200 articles
# Month: 2
# Number of pages: 1
# Scraped 4300 articles
# Month: 3
# Number of pages: 1
# Scraped 4400 articles
# Month: 4
# Number of pages: 1
# Scraped 4500 articles
# Month: 5
# Number of pages: 1
# Scraped 4600 articles
# Month: 6
# Number of pages: 1
# Scraped 4700 articles
# Scraped 4800 articles
# Month: 7
# Number of pages: 1
# Scraped 4900 articles
# Month: 8
# Number of pages: 1
# Scraped 5000 articles
# Month: 9
# Number of pages: 1
# Scraped 5100 articles
# Month: 10
# Number of pages: 0
# Scraped 5200 articles
# Month: 11
# Number of pages: 1
# Scraped 5300 articles
# Scraped 5400 articles
# Month: 12
# Number of pages: 1
# Scraped 5500 articles
# Year: 2013
# Month: 1
# Number of pages: 1
# Scraped 5600 articles
# Month: 2
# Number of pages: 1
# Scraped 5700 articles
# Month: 3
# Number of pages: 1
# Scraped 5800 articles
# Month: 4
# Number of pages: 1
# Scraped 5900 articles
# Month: 5
# Number of pages: 1
# Scraped 6000 articles
# Scraped 6100 articles
# Month: 6
# Number of pages: 1
# Scraped 6200 articles
# Month: 7
# Number of pages: 1
# Scraped 6300 articles
# Month: 8
# Number of pages: 1
# Scraped 6400 articles
# Month: 9
# Number of pages: 1
# Scraped 6500 articles
# Month: 10
# Number of pages: 1
# Scraped 6600 articles
# Scraped 6700 articles
# Month: 11
# Number of pages: 1
# Scraped 6800 articles
# Month: 12
# Number of pages: 1
# Scraped 6900 articles
# Year: 2014
# Month: 1
# Number of pages: 1
# Scraped 7000 articles
# Month: 2
# Number of pages: 1
# Scraped 7100 articles
# Month: 3
# Number of pages: 1
# Scraped 7200 articles
# Scraped 7300 articles
# Month: 4
# Number of pages: 1
# Scraped 7400 articles
# Month: 5
# Number of pages: 1
# Scraped 7500 articles
# Month: 6
# Number of pages: 1
# Scraped 7600 articles
# Month: 7
# Number of pages: 1
# Scraped 7700 articles
# Month: 8
# Number of pages: 1
# Scraped 7800 articles
# Month: 9
# Number of pages: 1
# Scraped 7900 articles
# Scraped 8000 articles
# Month: 10
# Number of pages: 1
# Scraped 8100 articles
# Month: 11
# Number of pages: 1
# Scraped 8200 articles
# Month: 12
# Number of pages: 1
# Scraped 8300 articles
# Year: 2015
# Month: 1
# Number of pages: 1
# Scraped 8400 articles
# Month: 2
# Number of pages: 1
# Scraped 8500 articles
# Scraped 8600 articles
# Month: 3
# Number of pages: 1
# Scraped 8700 articles
# Month: 4
# Number of pages: 1
# Scraped 8800 articles
# Month: 5
# Number of pages: 1
# Scraped 8900 articles
# Month: 6
# Number of pages: 1
# Scraped 9000 articles
# Month: 7
# Number of pages: 1
# Scraped 9100 articles
# Scraped 9200 articles
# Month: 8
# Number of pages: 1
# Scraped 9300 articles
# Month: 9
# Number of pages: 1
# Scraped 9400 articles
# Month: 10
# Number of pages: 1
# Scraped 9500 articles
# Month: 11
# Number of pages: 1
# Scraped 9600 articles
# Month: 12
# Number of pages: 1
# Scraped 9700 articles
# Scraped 9800 articles
# Year: 2016
# Month: 1
# Number of pages: 1
# Scraped 9900 articles
# Month: 2
# Number of pages: 1
# Scraped 10000 articles
# Month: 3
# Number of pages: 1
# Scraped 10100 articles
# Month: 4
# Number of pages: 1
# Scraped 10200 articles
# Month: 5
# Number of pages: 1
# Scraped 10300 articles
# Scraped 10400 articles
# Month: 6
# Number of pages: 1
# Scraped 10500 articles
# Month: 7
# Number of pages: 1
# Scraped 10600 articles
# Month: 8
# Number of pages: 1
# Scraped 10700 articles
# Month: 9
# Number of pages: 1
# Scraped 10800 articles
# Month: 10
# Number of pages: 1
# Scraped 10900 articles
# Scraped 11000 articles
# Month: 11
# Number of pages: 1
# Scraped 11100 articles
# Month: 12
# Number of pages: 1
# Scraped 11200 articles
# Year: 2017
# Month: 1
# Number of pages: 1
# Scraped 11300 articles
# Month: 2
# Number of pages: 1
# Scraped 11400 articles
# Month: 3
# Number of pages: 1
# Scraped 11500 articles
# Scraped 11600 articles
# Month: 4
# Number of pages: 1
# Scraped 11700 articles
# Month: 5
# Number of pages: 1
# Scraped 11800 articles
# Month: 6
# Number of pages: 1
# Scraped 11900 articles
# Month: 7
# Number of pages: 1
# Scraped 12000 articles
# Month: 8
# Number of pages: 1
# Scraped 12100 articles
# Scraped 12200 articles
# Month: 9
# Number of pages: 1
# Scraped 12300 articles
# Month: 10
# Number of pages: 1
# Scraped 12400 articles
# Month: 11
# Number of pages: 1
# Scraped 12500 articles
# Month: 12
# Number of pages: 1
# Scraped 12600 articles
# Year: 2018
# Month: 1
# Number of pages: 1
# Scraped 12700 articles
# Scraped 12800 articles
# Month: 2
# Number of pages: 1
# Scraped 12900 articles
# Month: 3
# Number of pages: 1
# Scraped 13000 articles
# Month: 4
# Number of pages: 1
# Scraped 13100 articles
# Month: 5
# Number of pages: 1
# Scraped 13200 articles
# Month: 6
# Number of pages: 1
# Scraped 13300 articles
# Scraped 13400 articles
# Month: 7
# Number of pages: 1
# Scraped 13500 articles
# Month: 8
# Number of pages: 1
# Scraped 13600 articles
# Month: 9
# Number of pages: 1
# Scraped 13700 articles
# Month: 10
# Number of pages: 1
# Scraped 13800 articles
# Month: 11
# Number of pages: 1
# Scraped 13900 articles
# Scraped 14000 articles
# Month: 12
# Number of pages: 1
# Scraped 14100 articles
# Year: 2019
# Month: 1
# Number of pages: 1
# Scraped 14200 articles
# Month: 2
# Number of pages: 1
# Scraped 14300 articles
# Month: 3
# Number of pages: 1
# Scraped 14400 articles
# Month: 4
# Number of pages: 1
# Scraped 14500 articles
# Month: 5
# Number of pages: 1
# Scraped 14600 articles
# Scraped 14700 articles
# Month: 6
# Number of pages: 1
# Scraped 14800 articles
# Month: 7
# Number of pages: 1
# Scraped 14900 articles
# Month: 8
# Number of pages: 1
# Scraped 15000 articles
# Month: 9
# Number of pages: 1
# Scraped 15100 articles
# Month: 10
# Number of pages: 1
# Scraped 15200 articles
# Scraped 15300 articles
# Month: 11
# Number of pages: 1
# Scraped 15400 articles
# Month: 12
# Number of pages: 1
# Scraped 15500 articles
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 15600 articles
# Month: 2
# Number of pages: 1
# Scraped 15700 articles
# Month: 3
# Number of pages: 1
# Scraped 15800 articles
# Scraped 15900 articles
# Month: 4
# Number of pages: 1
# Scraped 16000 articles
# Month: 5
# Number of pages: 1
# Scraped 16100 articles
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with stars category. Scraped 16138 articles
# 16138 articles of stars category scraped from tz_de
