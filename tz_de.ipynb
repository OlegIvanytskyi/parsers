# %%
from helper import *
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Driver [C:\Users\Oleg\.wdm\drivers\chromedriver\win32\84.0.4147.30\chromedriver.exe] found in cache

# %%
categories = {'travel' : 'reise', 'politics' : 'politik',
              'economy' : 'wirtschaft', 'food' : 'leben/genuss',
              'health' : 'leben/gesundheit', 'career' : 'leben/karriere',
              'pets' : 'leben/tiere' , 'gaming' : 'leben/games',
              'cinema' : 'leben/serien', 'auto' : 'auto',
              'sport' : 'sport', 'stars' : 'stars'}

# %%
for category, path in categories.items():
    print(f'Working with {category} category')
    
    lines = []
    page_num = 1
    
    for year in range(2009, 2021):
        print(f'Year: {year}')
        for month in range(1, 13):
            print(f'Month: {month}')
            
            page_num = 1
            month_str = f'0{month}' if month < 10 else str(month)
            
            while True:
                time.sleep(5)
                url = f'https://www.tz.de/{path}/archiv-{year}-{month_str}/index-vc-399169-{page_num}.html#id-swiper-399169'
                
                try:
                    driver.get(url)
                    page = driver.page_source
                    soup = BeautifulSoup(page, 'html.parser')

                    if page_num == 1:
                        page_counter = soup.find('div', class_='id-Swiper-navcountnavnew-inner')
                        if page_counter is None:
                            limit = 1
                        else:
                            limit = len(page_counter.find_all('a'))
                        print(f'Number of pages: {limit}')

                    div = soup.find('div', class_='id-LB id-LB--XL2 id-Teaser id-Teaser-el--listLeftStyle--LB')
                    if div is None:
                        break

                    divs = div.find_all('div', class_='id-LB-e--XL6_0c') + div.find_all('div', class_='id-LB-e--XL6_6')
                    if divs == []:
                        break

                    for div in divs:
                        teaser_headline = div.find('span', class_='id-Teaser-el-content-headline-text')
                        teaser = div.find('span', class_='id-Teaser-el-content-text-text')

                        if None in (teaser_headline, teaser):
                            continue

                        teaser_headline = teaser_headline.text.strip()
                        teaser = teaser.text.strip()

                        lines.append(teaser_headline)
                        lines.append(teaser)

                        if len(lines) % 100 == 0:
                            print(f'Scraped {len(lines)} lines')

                    page_num += 1
                    if page_num > limit:
                        break
                except:
                    break
        
    print(f'Finished working with {category} category. Scraped {len(lines)} lines')
    write_to_file(lines, category, 'tz_de')
# Out:
# Working with travel category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Scraped 100 lines
# Month: 4
# Number of pages: 1
# Scraped 200 lines
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 300 lines
# Month: 7
# Number of pages: 1
# Scraped 400 lines
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with travel category. Scraped 476 lines
# 476 lines of travel category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with politics category
# Year: 2020
# Month: 1
# Number of pages: 2
# Scraped 100 lines
# Scraped 200 lines
# Scraped 300 lines
# Scraped 400 lines
# Month: 2
# Number of pages: 3
# Scraped 500 lines
# Scraped 600 lines
# Scraped 700 lines
# Scraped 800 lines
# Scraped 900 lines
# Scraped 1000 lines
# Month: 3
# Number of pages: 2
# Scraped 1100 lines
# Scraped 1200 lines
# Scraped 1300 lines
# Scraped 1400 lines
# Month: 4
# Number of pages: 2
# Scraped 1500 lines
# Scraped 1600 lines
# Month: 5
# Number of pages: 2
# Scraped 1700 lines
# Scraped 1800 lines
# Scraped 1900 lines
# Scraped 2000 lines
# Month: 6
# Number of pages: 1
# Scraped 2100 lines
# Scraped 2200 lines
# Month: 7
# Number of pages: 1
# Scraped 2300 lines
# Scraped 2400 lines
# Month: 8
# Number of pages: 1
# Scraped 2500 lines
# Scraped 2600 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with politics category. Scraped 2612 lines
# 2612 lines of politics category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with economy category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 100 lines
# Month: 3
# Number of pages: 1
# Scraped 200 lines
# Month: 4
# Number of pages: 1
# Scraped 300 lines
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 400 lines
# Month: 7
# Number of pages: 1
# Scraped 500 lines
# Month: 8
# Number of pages: 1
# Scraped 600 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with economy category. Scraped 624 lines
# 624 lines of economy category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with food category
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 100 lines
# Month: 2
# Number of pages: 1
# Scraped 200 lines
# Month: 3
# Number of pages: 1
# Scraped 300 lines
# Month: 4
# Number of pages: 1
# Scraped 400 lines
# Scraped 500 lines
# Month: 5
# Number of pages: 1
# Scraped 600 lines
# Month: 6
# Number of pages: 1
# Scraped 700 lines
# Month: 7
# Number of pages: 1
# Scraped 800 lines
# Month: 8
# Number of pages: 1
# Scraped 900 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with food category. Scraped 952 lines
# 952 lines of food category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with health category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 100 lines
# Scraped 200 lines
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 300 lines
# Month: 5
# Number of pages: 1
# Scraped 400 lines
# Month: 6
# Number of pages: 1
# Scraped 500 lines
# Month: 7
# Number of pages: 1
# Scraped 600 lines
# Scraped 700 lines
# Scraped 800 lines
# Month: 8
# Number of pages: 1
# Scraped 900 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with health category. Scraped 900 lines
# 900 lines of health category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with career category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 100 lines
# Month: 3
# Number of pages: 1
# Scraped 200 lines
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Scraped 300 lines
# Month: 6
# Number of pages: 1
# Scraped 400 lines
# Month: 7
# Number of pages: 1
# Scraped 500 lines
# Month: 8
# Number of pages: 1
# Scraped 600 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with career category. Scraped 664 lines
# 664 lines of career category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with pets category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Month: 7
# Number of pages: 1
# Month: 8
# Number of pages: 1
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with pets category. Scraped 0 lines
# 0 lines of pets category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with gaming category
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 100 lines
# Scraped 200 lines
# Month: 2
# Number of pages: 1
# Scraped 300 lines
# Scraped 400 lines
# Month: 3
# Number of pages: 1
# Scraped 500 lines
# Scraped 600 lines
# Month: 4
# Number of pages: 1
# Scraped 700 lines
# Scraped 800 lines
# Scraped 900 lines
# Month: 5
# Number of pages: 1
# Scraped 1000 lines
# Month: 6
# Number of pages: 1
# Scraped 1100 lines
# Month: 7
# Number of pages: 1
# Scraped 1200 lines
# Scraped 1300 lines
# Month: 8
# Number of pages: 1
# Scraped 1400 lines
# Scraped 1500 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with gaming category. Scraped 1530 lines
# 1530 lines of gaming category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with cinema category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 100 lines
# Month: 3
# Number of pages: 1
# Month: 4
# Number of pages: 1
# Scraped 200 lines
# Scraped 300 lines
# Month: 5
# Number of pages: 1
# Month: 6
# Number of pages: 1
# Scraped 400 lines
# Month: 7
# Number of pages: 1
# Scraped 500 lines
# Month: 8
# Number of pages: 1
# Scraped 600 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with cinema category. Scraped 640 lines
# 640 lines of cinema category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with auto category
# Year: 2020
# Month: 1
# Number of pages: 1
# Month: 2
# Number of pages: 1
# Scraped 100 lines
# Month: 3
# Number of pages: 1
# Scraped 200 lines
# Month: 4
# Number of pages: 1
# Scraped 300 lines
# Month: 5
# Number of pages: 1
# Scraped 400 lines
# Month: 6
# Number of pages: 1
# Scraped 500 lines
# Month: 7
# Number of pages: 1
# Scraped 600 lines
# Scraped 700 lines
# Month: 8
# Number of pages: 1
# Scraped 800 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with auto category. Scraped 896 lines
# 896 lines of auto category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with sport category
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 100 lines
# Scraped 200 lines
# Month: 2
# Number of pages: 1
# Scraped 300 lines
# Scraped 400 lines
# Month: 3
# Number of pages: 1
# Scraped 500 lines
# Scraped 600 lines
# Scraped 700 lines
# Month: 4
# Number of pages: 1
# Scraped 800 lines
# Scraped 900 lines
# Month: 5
# Number of pages: 1
# Scraped 1000 lines
# Scraped 1100 lines
# Month: 6
# Number of pages: 1
# Scraped 1200 lines
# Scraped 1300 lines
# Scraped 1400 lines
# Month: 7
# Number of pages: 1
# Scraped 1500 lines
# Scraped 1600 lines
# Month: 8
# Number of pages: 4
# Scraped 1700 lines
# Scraped 1800 lines
# Scraped 1900 lines
# Scraped 2000 lines
# Scraped 2100 lines
# Scraped 2200 lines
# Scraped 2300 lines
# Scraped 2400 lines
# Scraped 2500 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with sport category. Scraped 2582 lines
# 2582 lines of sport category have been scraped from tz_de
#
# ______________________________________________________________________________
# Working with stars category
# Year: 2020
# Month: 1
# Number of pages: 1
# Scraped 100 lines
# Scraped 200 lines
# Month: 2
# Number of pages: 1
# Scraped 300 lines
# Scraped 400 lines
# Month: 3
# Number of pages: 1
# Scraped 500 lines
# Scraped 600 lines
# Scraped 700 lines
# Month: 4
# Number of pages: 1
# Scraped 800 lines
# Scraped 900 lines
# Month: 5
# Number of pages: 1
# Scraped 1000 lines
# Scraped 1100 lines
# Month: 6
# Number of pages: 1
# Scraped 1200 lines
# Scraped 1300 lines
# Scraped 1400 lines
# Month: 7
# Number of pages: 1
# Scraped 1500 lines
# Scraped 1600 lines
# Month: 8
# Number of pages: 1
# Scraped 1700 lines
# Scraped 1800 lines
# Scraped 1900 lines
# Month: 9
# Number of pages: 1
# Month: 10
# Number of pages: 1
# Month: 11
# Number of pages: 1
# Month: 12
# Number of pages: 1
# Finished working with stars category. Scraped 1918 lines
# 1918 lines of stars category have been scraped from tz_de
#
# ______________________________________________________________________________
